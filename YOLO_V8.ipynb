# %% [markdown]
# <a href="https://colab.research.google.com/github/mine1808/YOLOV8-PMLD/blob/main/YOLO_V8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.134 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.7/112.6 GB disk)

# %%
# !yolo segment train model=yolov8n-seg.pt data="/content/drive/MyDrive/PMLD/PMLD YOLO V8/data.yaml"
# Out:
# Ultralytics 8.3.134 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo segment predict model="/content/runs/segment/train2/weights/best.pt" source="/content/drive/MyDrive/PMLD/PMLD YOLO V8/test/images/0004_aug_4_png.rf.b143dcc1aa885699a80e074b99870f72.jpg"
# Out:
# Ultralytics 8.3.134 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,454 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PMLD/PMLD YOLO V8/test/images/0004_aug_4_png.rf.b143dcc1aa885699a80e074b99870f72.jpg: 640x640 33 Sandstones, 77 Siltstones, 10.5ms
# Speed: 3.7ms preprocess, 10.5ms inference, 225.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
